# %%
import torch
import torchaudio

torch.random.manual_seed(0)
device = "cuda" if torch.cuda.is_available() else "cpu"

print(torch.__version__)
print(torchaudio.__version__)
print(device)
# Out:
# 2.8.0
# 2.8.0
# cpu

# %%
import IPython
import matplotlib.pyplot as plt

# %%
symbols = "_-!'(),.:;? abcdefghijklmnopqrstuvwxyz"
look_up = {s: i for i, s in enumerate(symbols)}
symbols = set(symbols)


def text_to_sequence(text):
    text = text.lower()
    return [look_up[s] for s in text if s in symbols]


text = "Hello world! Text to speech!"
print(text_to_sequence(text))
# Out:
# [19, 16, 23, 23, 26, 11, 34, 26, 29, 23, 15, 2, 11, 31, 16, 35, 31, 11, 31, 26, 11, 30, 27, 16, 16, 14, 19, 2]

# %%
processor = torchaudio.pipelines.TACOTRON2_WAVERNN_CHAR_LJSPEECH.get_text_processor()

text = "Hello world! Text to speech!"
processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# tensor([[19, 16, 23, 23, 26, 11, 34, 26, 29, 23, 15,  2, 11, 31, 16, 35, 31, 11,
#          31, 26, 11, 30, 27, 16, 16, 14, 19,  2]])
# tensor([28], dtype=torch.int32)

# %%
print([processor.tokens[i] for i in processed[0, : lengths[0]]])
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', ' ', 't', 'e', 'x', 't', ' ', 't', 'o', ' ', 's', 'p', 'e', 'e', 'c', 'h', '!']

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()

text = "Hello world! Text to speech!"
with torch.inference_mode():
    processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# tensor([[54, 20, 65, 69, 11, 92, 44, 65, 38,  2, 11, 81, 40, 64, 79, 81, 11, 81,
#          20, 11, 79, 77, 59, 37,  2]])
# tensor([25], dtype=torch.int32)
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
pip install deep_phonemizer
# Out:
# Requirement already satisfied: deep_phonemizer in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (2.8.0)
# Requirement already satisfied: tqdm>=4.38.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (6.0.2)
# Requirement already satisfied: tensorboard in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (2.20.0)
# Requirement already satisfied: certifi>=2022.12.7 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (2025.8.3)
# Requirement already satisfied: wheel>=0.38.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (0.45.1)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (78.1.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (1.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.2.0->deep_phonemizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from jinja2->torch>=1.2.0->deep_phonemizer) (3.0.2)
# Requirement already satisfied: absl-py>=0.4 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (3.9)
# Requirement already satisfied: numpy>=1.12.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (2.2.6)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (25.0)
# Requirement already satisfied: pillow in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (6.32.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (3.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()

text = "Hello world! Text to speech!"
with torch.inference_mode():
    processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# tensor([[54, 20, 65, 69, 11, 92, 44, 65, 38,  2, 11, 81, 40, 64, 79, 81, 11, 81,
#          20, 11, 79, 77, 59, 37,  2]])
# tensor([25], dtype=torch.int32)

# %%
print([processor.tokens[i] for i in processed[0, : lengths[0]]])
# Out:
# ['HH', 'AH', 'L', 'OW', ' ', 'W', 'ER', 'L', 'D', '!', ' ', 'T', 'EH', 'K', 'S', 'T', ' ', 'T', 'AH', ' ', 'S', 'P', 'IY', 'CH', '!']

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH
processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)

text = "Hello world! Text to speech!"

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, _, _ = tacotron2.infer(processed, lengths)


_ = plt.imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")

# %%
def plot():
    fig, ax = plt.subplots(3, 1)
    for i in range(3):
        with torch.inference_mode():
            spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
        print(spec[0].shape)
        ax[i].imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")


plot()
# Out:
# torch.Size([80, 182])
# torch.Size([80, 155])
# torch.Size([80, 182])

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)
vocoder = bundle.get_vocoder().to(device)

text = "Hello world! Text to speech!"

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
    waveforms, lengths = vocoder(spec, spec_lengths)

# %%
def plot(waveforms, spec, sample_rate):
    waveforms = waveforms.cpu().detach()

    fig, [ax1, ax2] = plt.subplots(2, 1)
    ax1.plot(waveforms[0])
    ax1.set_xlim(0, waveforms.size(-1))
    ax1.grid(True)
    ax2.imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")
    return IPython.display.Audio(waveforms[0:1], rate=sample_rate)


plot(waveforms, spec, vocoder.sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
bundle = torchaudio.pipelines.TACOTRON2_GRIFFINLIM_PHONE_LJSPEECH

processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)
vocoder = bundle.get_vocoder().to(device)

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
waveforms, lengths = vocoder(spec, spec_lengths)

# %%
plot(waveforms, spec, vocoder.sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Workaround to load model mapped on GPU
# https://stackoverflow.com/a/61840832
waveglow = torch.hub.load(
    "NVIDIA/DeepLearningExamples:torchhub",
    "nvidia_waveglow",
    model_math="fp32",
    pretrained=False,
)
checkpoint = torch.hub.load_state_dict_from_url(
    "https://api.ngc.nvidia.com/v2/models/nvidia/waveglowpyt_fp32/versions/1/files/nvidia_waveglowpyt_fp32_20190306.pth",  # noqa: E501
    progress=False,
    map_location=device,
)
state_dict = {key.replace("module.", ""): value for key, value in checkpoint["state_dict"].items()}

waveglow.load_state_dict(state_dict)
waveglow = waveglow.remove_weightnorm(waveglow)
waveglow = waveglow.to(device)
waveglow.eval()

with torch.no_grad():
    waveforms = waveglow.infer(spec)
# Out:
# Using cache found in /Users/chaejang-u/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# /Users/chaejang-u/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /Users/chaejang-u/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Downloading: "https://api.ngc.nvidia.com/v2/models/nvidia/waveglowpyt_fp32/versions/1/files/nvidia_waveglowpyt_fp32_20190306.pth" to /Users/chaejang-u/.cache/torch/hub/checkpoints/nvidia_waveglowpyt_fp32_20190306.pth

# %%
plot(waveforms, spec, 22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
