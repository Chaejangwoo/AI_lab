# %%
import torch
import torchaudio

# 언더바를 한 개(_)에서 두 개(__)로 수정합니다.
print(f"PyTorch version: {torch.__version__}")
print(f"Torchaudio version: {torchaudio.__version__}")


# 2. Mac의 GPU(MPS) 사용 가능 여부 확인
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("\n✓ MPS is available! Device count: 1")
    print(f"Current MPS device: Apple's Metal GPU")
else:
    device = torch.device("cpu")
    print("\n✓ CUDA is available! Device count: 0") # 강의자료 형식에 맞춤
    print("Current device: CPU")


# 3. 테스트 텐서 생성 및 정보 출력
try:
    test_tensor = torch.tensor([1, 2, 3, 4, 5], device=device)
    print(f"✓ Test tensor created: {test_tensor}")
    print(f"Tensor shape: {test_tensor.shape}")
    print(f"Tensor device: {test_tensor.device}")

    # 4. 기본 연산 테스트 (제곱)
    squared_tensor = test_tensor.pow(2)
    print(f"✓ Basic operation test (squaring): {squared_tensor}")

    print("\nPyTorch is working correctly!")

except Exception as e:
    print(f"\nAn error occurred: {e}")
# Out:
# PyTorch version: 2.8.0
# Torchaudio version: 2.8.0
#
# ✓ MPS is available! Device count: 1
# Current MPS device: Apple's Metal GPU
# ✓ Test tensor created: tensor([1, 2, 3, 4, 5], device='mps:0')
# Tensor shape: torch.Size([5])
# Tensor device: mps:0
# ✓ Basic operation test (squaring): tensor([ 1,  4,  9, 16, 25], device='mps:0')
#
# PyTorch is working correctly!

# %%
import io
import os
import tarfile
import tempfile

import boto3
import matplotlib.pyplot as plt
import requests
from botocore import UNSIGNED
from botocore.config import Config
from IPython.display import Audio
from torchaudio.utils import download_asset

SAMPLE_GSM = download_asset("tutorial-assets/steam-train-whistle-daniel_simon.gsm")
SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SAMPLE_WAV_8000 = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042-8000hz.wav")


def _hide_seek(obj):
    class _wrapper:
        def __init__(self, obj):
            self.obj = obj

        def read(self, n):
            return self.obj.read(n)

    return _wrapper(obj)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       3 import tarfile
#       4 import tempfile
# ----> 6 import boto3
#       7 import matplotlib.pyplot as plt
#       8 import requests
#
# ModuleNotFoundError: No module named 'boto3'

# %%
import io
import os
import tarfile
import tempfile

import boto3
import matplotlib.pyplot as plt
import requests
from botocore import UNSIGNED
from botocore.config import Config
from IPython.display import Audio
from torchaudio.utils import download_asset

SAMPLE_GSM = download_asset("tutorial-assets/steam-train-whistle-daniel_simon.gsm")
SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SAMPLE_WAV_8000 = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042-8000hz.wav")


def _hide_seek(obj):
    class _wrapper:
        def __init__(self, obj):
            self.obj = obj

        def read(self, n):
            return self.obj.read(n)

    return _wrapper(obj)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 import tarfile
#       4 import tempfile
# ----> 6 import boto3
#       7 import matplotlib.pyplot as plt
#       8 import requests
#
# ModuleNotFoundError: No module named 'boto3'

# %%
# !pip install boto3 requests
# Out:
# Collecting boto3
#   Using cached boto3-1.40.33-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (2.32.5)
# Collecting botocore<1.41.0,>=1.40.33 (from boto3)
#   Using cached botocore-1.40.33-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Using cached s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.33->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.33->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.33->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (2025.8.3)
# Using cached boto3-1.40.33-py3-none-any.whl (139 kB)
# Using cached botocore-1.40.33-py3-none-any.whl (14.0 MB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [boto3]━━━━━ 1/4 [botocore]
# Successfully installed boto3-1.40.33 botocore-1.40.33 jmespath-1.0.1 s3transfer-0.14.0

# %%
import io
import os
import tarfile
import tempfile

import boto3
import matplotlib.pyplot as plt
import requests
from botocore import UNSIGNED
from botocore.config import Config
from IPython.display import Audio
from torchaudio.utils import download_asset

SAMPLE_GSM = download_asset("tutorial-assets/steam-train-whistle-daniel_simon.gsm")
SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SAMPLE_WAV_8000 = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042-8000hz.wav")


def _hide_seek(obj):
    class _wrapper:
        def __init__(self, obj):
            self.obj = obj

        def read(self, n):
            return self.obj.read(n)

    return _wrapper(obj)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       4 import tempfile
#       6 import boto3
# ----> 7 import matplotlib.pyplot as plt
#       8 import requests
#       9 from botocore import UNSIGNED
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.4-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp310-cp310-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 10.4 MB/s  0:00:005.0 MB/s eta 0:00:01:01
# Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 19.1 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Downloading pyparsing-3.2.4-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib] 5/6 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.60.0 kiwisolver-1.4.9 matplotlib-3.10.6 pyparsing-3.2.4

# %%
import io
import os
import tarfile
import tempfile

import boto3
import matplotlib.pyplot as plt
import requests
from botocore import UNSIGNED
from botocore.config import Config
from IPython.display import Audio
from torchaudio.utils import download_asset

SAMPLE_GSM = download_asset("tutorial-assets/steam-train-whistle-daniel_simon.gsm")
SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
SAMPLE_WAV_8000 = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042-8000hz.wav")


def _hide_seek(obj):
    class _wrapper:
        def __init__(self, obj):
            self.obj = obj

        def read(self, n):
            return self.obj.read(n)

    return _wrapper(obj)
# Out:
# /var/folders/hy/4l8rh64x5jq6wnmxtmp4ddb00000gn/T/ipykernel_29229/2415713283.py:14: UserWarning: torchaudio.utils.download.download_asset has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   SAMPLE_GSM = download_asset("tutorial-assets/steam-train-whistle-daniel_simon.gsm")
# 100.0%
# /var/folders/hy/4l8rh64x5jq6wnmxtmp4ddb00000gn/T/ipykernel_29229/2415713283.py:15: UserWarning: torchaudio.utils.download.download_asset has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
# 100.0%
# /var/folders/hy/4l8rh64x5jq6wnmxtmp4ddb00000gn/T/ipykernel_29229/2415713283.py:16: UserWarning: torchaudio.utils.download.download_asset has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   SAMPLE_WAV_8000 = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042-8000hz.wav")
# 100.0%

# %%
metadata = torchaudio.info(SAMPLE_WAV)
print(metadata)
# Out:
# /var/folders/hy/4l8rh64x5jq6wnmxtmp4ddb00000gn/T/ipykernel_29229/3458049858.py:1: UserWarning: torchaudio._backend.utils.info has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   metadata = torchaudio.info(SAMPLE_WAV)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metadata = torchaudio.info(SAMPLE_WAV)
#       2 print(metadata)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_internal/module_utils.py:71, in wrap_deprecated.<locals>.wrapped(*args, **kwargs)
#      69     message += f' It will be removed from {"a future" if version is None else "the " + str(version)} release. '
#      70 warnings.warn(message, stacklevel=2)
# ---> 71 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/utils.py:99, in get_info_func.<locals>.info(uri, format, buffer_size, backend)
#      57 def info(
#      58     uri: Union[BinaryIO, str, os.PathLike],
#      59     format: Optional[str] = None,
#      60     buffer_size: int = 4096,
#      61     backend: Optional[str] = None,
#      62 ) -> AudioMetaData:
#      63     """Get signal information of an audio file.
#      64
#      65     Note:
#    (...)
#      97         AudioMetaData
#      98     """
# ---> 99     backend = dispatcher(uri, format, backend)
#     100     return backend.info(uri, format, buffer_size)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/utils.py:55, in get_info_func.<locals>.dispatcher(uri, format, backend_name)
#      53     if backend.can_decode(uri, format):
#      54         return backend
# ---> 55 raise RuntimeError(f"Couldn't find appropriate backend to handle uri {uri} and format {format}.")
#
# RuntimeError: Couldn't find appropriate backend to handle uri /Users/chaejang-u/.cache/torch/hub/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav and format None.

# %%
# !pip install soundfile
# Out:
# Collecting soundfile
#   Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from soundfile) (2.2.6)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.23)
# Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.9 MB/s  0:00:00
# Installing collected packages: soundfile
# Successfully installed soundfile-0.13.1

# %%
import torch
import torchaudio
from torchaudio.utils import download_asset

# 샘플 파일 경로는 그대로 사용합니다.
SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")

# torchaudio.info() 대신 torchaudio.load()를 사용합니다.
try:
    waveform, sample_rate = torchaudio.load(SAMPLE_WAV)

    # 불러온 데이터로부터 필요한 정보를 얻습니다.
    num_channels = waveform.shape[0]
    num_frames = waveform.shape[1]
    duration_seconds = num_frames / sample_rate

    print("--- Audio Metadata ---")
    print(f"Sample Rate: {sample_rate}")
    print(f"Number of Channels: {num_channels}")
    print(f"Total Frames: {num_frames}")
    print(f"Duration: {duration_seconds:.2f} seconds")

except Exception as e:
    print(f"오류가 발생했습니다: {e}")
    print("soundfile 라이브러리를 설치하고 커널을 재시작했는지 확인해주세요.")
# Out:
# --- Audio Metadata ---
# Sample Rate: 16000
# Number of Channels: 1
# Total Frames: 54400
# Duration: 3.40 seconds
# /var/folders/hy/4l8rh64x5jq6wnmxtmp4ddb00000gn/T/ipykernel_31769/1812085694.py:6: UserWarning: torchaudio.utils.download.download_asset has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   SAMPLE_WAV = download_asset("tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav")
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(

# %%
url = "https://download.pytorch.org/torchaudio/tutorial-assets/steam-train-whistle-daniel_simon.wav"
with requests.get(url, stream=True) as response:
    metadata = torchaudio.info(_hide_seek(response.raw))
print(metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 url = "https://download.pytorch.org/torchaudio/tutorial-assets/steam-train-whistle-daniel_simon.wav"
# ----> 2 with requests.get(url, stream=True) as response:
#       3     metadata = torchaudio.info(_hide_seek(response.raw))
#       4 print(metadata)
#
# NameError: name 'requests' is not defined

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests) (2025.8.3)

# %%
url = "https://download.pytorch.org/torchaudio/tutorial-assets/steam-train-whistle-daniel_simon.wav"
with requests.get(url, stream=True) as response:
    metadata = torchaudio.info(_hide_seek(response.raw))
print(metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 url = "https://download.pytorch.org/torchaudio/tutorial-assets/steam-train-whistle-daniel_simon.wav"
# ----> 2 with requests.get(url, stream=True) as response:
#       3     metadata = torchaudio.info(_hide_seek(response.raw))
#       4 print(metadata)
#
# NameError: name 'requests' is not defined

# %%
import matplotlib.pyplot as plt
from IPython.display import Audio

# 1. waveform 텐서를 그래프로 그려서 눈으로 확인하기
print("오디오 파형(Waveform):")
plt.figure()
plt.plot(waveform.t().numpy())
plt.title("Waveform")
plt.show()

# 2. Jupyter Notebook에서 직접 오디오 들어보기
print("오디오 재생:")
Audio(waveform.numpy(), rate=sample_rate)
# Out:
# 오디오 파형(Waveform):
# 오디오 재생:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load audio data as HTTP request
url = "https://download.pytorch.org/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav"
with requests.get(url, stream=True) as response:
    waveform, sample_rate = torchaudio.load(_hide_seek(response.raw))
plot_specgram(waveform, sample_rate, title="HTTP datasource")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Load audio data as HTTP request
#       2 url = "https://download.pytorch.org/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav"
# ----> 3 with requests.get(url, stream=True) as response:
#       4     waveform, sample_rate = torchaudio.load(_hide_seek(response.raw))
#       5 plot_specgram(waveform, sample_rate, title="HTTP datasource")
#
# NameError: name 'requests' is not defined

# %%
import requests  # <-- 이 줄을 추가하여 requests 라이브러리를 불러옵니다.
import torchaudio

# --- 이전에 정의했던 함수들이 필요할 수 있습니다 ---
# 만약 _hide_seek 함수가 정의된 셀을 실행하지 않았다면, 여기서 다시 정의해야 합니다.
def _hide_seek(obj):
    class _wrapper:
        def __init__(self, obj):
            self.obj = obj
        def read(self, n):
            return self.obj.read(n)
    return _wrapper(obj)

# 만약 plot_specgram 함수가 정의된 셀을 실행하지 않았다면, 여기서 다시 정의해야 합니다.
# (아래는 튜토리얼의 plot_specgram 함수 예시입니다)
def plot_specgram(waveform, sample_rate, title="Spectrogram"):
    import matplotlib.pyplot as plt
    import torch
    
    waveform = waveform.numpy()
    num_channels, num_frames = waveform.shape
    
    figure, axes = plt.subplots(num_channels, 1)
    if num_channels == 1:
        axes = [axes]
    for c in range(num_channels):
        axes[c].specgram(waveform[c], Fs=sample_rate)
        if num_channels > 1:
            axes[c].set_ylabel(f'Channel {c+1}')
    figure.suptitle(title)
    plt.show()
# ---------------------------------------------------


# 이제 URL에서 직접 오디오를 불러옵니다
url = "https://download.pytorch.org/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav"

with requests.get(url, stream=True) as response:
    waveform, sample_rate = torchaudio.load(_hide_seek(response.raw))

plot_specgram(waveform, sample_rate, title="HTTP datasource")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 39
#      36 url = "https://download.pytorch.org/torchaudio/tutorial-assets/Lab41-SRI-VOiCES-src-sp0307-ch127535-sg0042.wav"
#      38 with requests.get(url, stream=True) as response:
# ---> 39     waveform, sample_rate = torchaudio.load(_hide_seek(response.raw))
#      41 plot_specgram(waveform, sample_rate, title="HTTP datasource")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/utils.py:222, in get_load_func.<locals>.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     213 warnings.warn(
#     214     "In 2.9, this function's implementation will be changed to use "
#     215     "torchaudio.load_with_torchcodec` under the hood. Some "
#    (...)
#     219     "https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder."
#     220 )
#     221 backend = dispatcher(uri, format, backend)
# --> 222 return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/soundfile.py:27, in SoundfileBackend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#      17 @staticmethod
#      18 def load(
#      19     uri: Union[BinaryIO, str, os.PathLike],
#    (...)
#      25     buffer_size: int = 4096,
#      26 ) -> Tuple[torch.Tensor, int]:
# ---> 27     return soundfile_backend.load(uri, frame_offset, num_frames, normalize, channels_first, format)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/_backend/soundfile_backend.py:221, in load(filepath, frame_offset, num_frames, normalize, channels_first, format)
#     139 @_requires_soundfile
#     140 def load(
#     141     filepath: str,
#    (...)
#     146     format: Optional[str] = None,
#     147 ) -> Tuple[torch.Tensor, int]:
#     148     """Load audio data from file.
#     149
#     150     Note:
#    (...)
#     219             `[channel, time]` else `[time, channel]`.
#     220     """
# --> 221     with soundfile.SoundFile(filepath, "r") as file_:
#     222         if file_.format != "WAV" or normalize:
#     223             dtype = "float32"
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     687 self._bitrate_mode = bitrate_mode
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#     693     self.seek(0)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/soundfile.py:1261, in SoundFile._open(self, file, mode_int, closefd)
#    1258     file_ptr = _snd.sf_open_virtual(self._init_virtual_io(file),
#    1259                                     mode_int, self._info, _ffi.NULL)
#    1260 else:
# -> 1261     raise TypeError("Invalid file: {0!r}".format(self.name))
#    1262 if file_ptr == _ffi.NULL:
#    1263     # get the actual error code
#    1264     err = _snd.sf_error(file_ptr)
#
# TypeError: Invalid file: <__main__._hide_seek.<locals>._wrapper object at 0x10ad7ded0>

# %%
import math
import timeit

import librosa
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import pandas as pd
import resampy
from IPython.display import Audio

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

DEFAULT_OFFSET = 201


def _get_log_freq(sample_rate, max_sweep_rate, offset):
    """Get freqs evenly spaced out in log-scale, between [0, max_sweep_rate // 2]

    offset is used to avoid negative infinity `log(offset + x)`.

    """
    start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
    return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset


def _get_inverse_log_freq(freq, sample_rate, offset):
    """Find the time where the given frequency is given by _get_log_freq"""
    half = sample_rate // 2
    return sample_rate * (math.log(1 + freq / offset) / math.log(1 + half / offset))


def _get_freq_ticks(sample_rate, offset, f_max):
    # Given the original sample rate used for generating the sweep,
    # find the x-axis value where the log-scale major frequency values fall in
    times, freq = [], []
    for exp in range(2, 5):
        for v in range(1, 10):
            f = v * 10**exp
            if f < sample_rate // 2:
                t = _get_inverse_log_freq(f, sample_rate, offset) / sample_rate
                times.append(t)
                freq.append(f)
    t_max = _get_inverse_log_freq(f_max, sample_rate, offset) / sample_rate
    times.append(t_max)
    freq.append(f_max)
    return times, freq


def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
    max_sweep_rate = sample_rate
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    delta = 2 * math.pi * freq / sample_rate
    cummulative = torch.cumsum(delta, dim=0)
    signal = torch.sin(cummulative).unsqueeze(dim=0)
    return signal


def plot_sweep(
    waveform,
    sample_rate,
    title,
    max_sweep_rate=48000,
    offset=DEFAULT_OFFSET,
):
    x_ticks = [100, 500, 1000, 5000, 10000, 20000, max_sweep_rate // 2]
    y_ticks = [1000, 5000, 10000, 20000, sample_rate // 2]

    time, freq = _get_freq_ticks(max_sweep_rate, offset, sample_rate // 2)
    freq_x = [f if f in x_ticks and f <= max_sweep_rate // 2 else None for f in freq]
    freq_y = [f for f in freq if f in y_ticks and 1000 <= f <= sample_rate // 2]

    figure, axis = plt.subplots(1, 1)
    _, _, _, cax = axis.specgram(waveform[0].numpy(), Fs=sample_rate)
    plt.xticks(time, freq_x)
    plt.yticks(freq_y, freq_y)
    axis.set_xlabel("Original Signal Frequency (Hz, log scale)")
    axis.set_ylabel("Waveform Frequency (Hz)")
    axis.xaxis.grid(True, alpha=0.67)
    axis.yaxis.grid(True, alpha=0.67)
    figure.suptitle(f"{title} (sample rate: {sample_rate} Hz)")
    plt.colorbar(cax)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 import math
#       2 import timeit
# ----> 4 import librosa
#       5 import matplotlib.colors as mcolors
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'librosa'

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.22.3 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from librosa) (2.2.6)
# Collecting scipy>=1.6.0 (from librosa)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting scikit-learn>=1.1.0 (from librosa)
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting joblib>=1.0 (from librosa)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from librosa) (0.13.1)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-1.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from librosa) (4.15.0)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.1-cp310-cp310-macosx_11_0_arm64.whl (78 kB)
# Downloading numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.6 MB/s  0:00:00m 6.7 MB/s eta 0:00:01
# Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 2.9 MB/s  0:00:09a 0:00:010:00:01:02
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.0 MB/s  0:00:02 eta 0:00:010:00:01
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 3.5 MB/s  0:00:06m 3.5 MB/s eta 0:00:01
# Downloading soxr-1.0.0-cp310-cp310-macosx_11_0_arm64.whl (164 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, soxr, scipy, msgpack, llvmlite, lazy_loader, joblib, audioread, scikit-learn, pooch, numba, librosa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [librosa];237m━━━ 11/12 [librosa]earn]
# Successfully installed audioread-3.0.1 joblib-1.5.2 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.44.0 msgpack-1.1.1 numba-0.61.2 pooch-1.8.2 scikit-learn-1.7.2 scipy-1.15.3 soxr-1.0.0 threadpoolctl-3.6.0

# %%
import math
import timeit

import librosa
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import pandas as pd
import resampy
from IPython.display import Audio

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

DEFAULT_OFFSET = 201


def _get_log_freq(sample_rate, max_sweep_rate, offset):
    """Get freqs evenly spaced out in log-scale, between [0, max_sweep_rate // 2]

    offset is used to avoid negative infinity `log(offset + x)`.

    """
    start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
    return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset


def _get_inverse_log_freq(freq, sample_rate, offset):
    """Find the time where the given frequency is given by _get_log_freq"""
    half = sample_rate // 2
    return sample_rate * (math.log(1 + freq / offset) / math.log(1 + half / offset))


def _get_freq_ticks(sample_rate, offset, f_max):
    # Given the original sample rate used for generating the sweep,
    # find the x-axis value where the log-scale major frequency values fall in
    times, freq = [], []
    for exp in range(2, 5):
        for v in range(1, 10):
            f = v * 10**exp
            if f < sample_rate // 2:
                t = _get_inverse_log_freq(f, sample_rate, offset) / sample_rate
                times.append(t)
                freq.append(f)
    t_max = _get_inverse_log_freq(f_max, sample_rate, offset) / sample_rate
    times.append(t_max)
    freq.append(f_max)
    return times, freq


def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
    max_sweep_rate = sample_rate
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    delta = 2 * math.pi * freq / sample_rate
    cummulative = torch.cumsum(delta, dim=0)
    signal = torch.sin(cummulative).unsqueeze(dim=0)
    return signal


def plot_sweep(
    waveform,
    sample_rate,
    title,
    max_sweep_rate=48000,
    offset=DEFAULT_OFFSET,
):
    x_ticks = [100, 500, 1000, 5000, 10000, 20000, max_sweep_rate // 2]
    y_ticks = [1000, 5000, 10000, 20000, sample_rate // 2]

    time, freq = _get_freq_ticks(max_sweep_rate, offset, sample_rate // 2)
    freq_x = [f if f in x_ticks and f <= max_sweep_rate // 2 else None for f in freq]
    freq_y = [f for f in freq if f in y_ticks and 1000 <= f <= sample_rate // 2]

    figure, axis = plt.subplots(1, 1)
    _, _, _, cax = axis.specgram(waveform[0].numpy(), Fs=sample_rate)
    plt.xticks(time, freq_x)
    plt.yticks(freq_y, freq_y)
    axis.set_xlabel("Original Signal Frequency (Hz, log scale)")
    axis.set_ylabel("Waveform Frequency (Hz)")
    axis.xaxis.grid(True, alpha=0.67)
    axis.yaxis.grid(True, alpha=0.67)
    figure.suptitle(f"{title} (sample rate: {sample_rate} Hz)")
    plt.colorbar(cax)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import matplotlib.colors as mcolors
#       6 import matplotlib.pyplot as plt
# ----> 7 import pandas as pd
#       8 import resampy
#       9 from IPython.display import Audio
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 47.1 MB/s  0:00:00.8 MB/s eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]━━━━━━━━━━━ 2/3 [pandas]
# Successfully installed pandas-2.3.2 pytz-2025.2 tzdata-2025.2

# %%
# !pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from resampy) (2.2.6)
# Requirement already satisfied: numba>=0.53 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from resampy) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from numba>=0.53->resampy) (0.44.0)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.8 MB/s  0:00:00
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3

# %%
# !pip install Ipython
# Out:
# Requirement already satisfied: Ipython in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (8.30.0)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (2.19.1)
# Requirement already satisfied: stack-data in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (5.14.3)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (4.15.0)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from Ipython) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->Ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from jedi>=0.16->Ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from pexpect>4.3->Ipython) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from stack-data->Ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from stack-data->Ipython) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from stack-data->Ipython) (0.2.3)

# %%
import math
import timeit

import librosa
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import pandas as pd
import resampy
from IPython.display import Audio

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

DEFAULT_OFFSET = 201


def _get_log_freq(sample_rate, max_sweep_rate, offset):
    """Get freqs evenly spaced out in log-scale, between [0, max_sweep_rate // 2]

    offset is used to avoid negative infinity `log(offset + x)`.

    """
    start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
    return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset


def _get_inverse_log_freq(freq, sample_rate, offset):
    """Find the time where the given frequency is given by _get_log_freq"""
    half = sample_rate // 2
    return sample_rate * (math.log(1 + freq / offset) / math.log(1 + half / offset))


def _get_freq_ticks(sample_rate, offset, f_max):
    # Given the original sample rate used for generating the sweep,
    # find the x-axis value where the log-scale major frequency values fall in
    times, freq = [], []
    for exp in range(2, 5):
        for v in range(1, 10):
            f = v * 10**exp
            if f < sample_rate // 2:
                t = _get_inverse_log_freq(f, sample_rate, offset) / sample_rate
                times.append(t)
                freq.append(f)
    t_max = _get_inverse_log_freq(f_max, sample_rate, offset) / sample_rate
    times.append(t_max)
    freq.append(f_max)
    return times, freq


def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
    max_sweep_rate = sample_rate
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    delta = 2 * math.pi * freq / sample_rate
    cummulative = torch.cumsum(delta, dim=0)
    signal = torch.sin(cummulative).unsqueeze(dim=0)
    return signal


def plot_sweep(
    waveform,
    sample_rate,
    title,
    max_sweep_rate=48000,
    offset=DEFAULT_OFFSET,
):
    x_ticks = [100, 500, 1000, 5000, 10000, 20000, max_sweep_rate // 2]
    y_ticks = [1000, 5000, 10000, 20000, sample_rate // 2]

    time, freq = _get_freq_ticks(max_sweep_rate, offset, sample_rate // 2)
    freq_x = [f if f in x_ticks and f <= max_sweep_rate // 2 else None for f in freq]
    freq_y = [f for f in freq if f in y_ticks and 1000 <= f <= sample_rate // 2]

    figure, axis = plt.subplots(1, 1)
    _, _, _, cax = axis.specgram(waveform[0].numpy(), Fs=sample_rate)
    plt.xticks(time, freq_x)
    plt.yticks(freq_y, freq_y)
    axis.set_xlabel("Original Signal Frequency (Hz, log scale)")
    axis.set_ylabel("Waveform Frequency (Hz)")
    axis.xaxis.grid(True, alpha=0.67)
    axis.yaxis.grid(True, alpha=0.67)
    figure.suptitle(f"{title} (sample rate: {sample_rate} Hz)")
    plt.colorbar(cax)

# %%
sample_rate = 48000
waveform = get_sine_sweep(sample_rate)

plot_sweep(waveform, sample_rate, title="Original Waveform")
Audio(waveform.numpy()[0], rate=sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 sample_rate = 48000
# ----> 2 waveform = get_sine_sweep(sample_rate)
#       4 plot_sweep(waveform, sample_rate, title="Original Waveform")
#       5 Audio(waveform.numpy()[0], rate=sample_rate)
#
# Cell In[5], line 52, in get_sine_sweep(sample_rate, offset)
#      50 def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
#      51     max_sweep_rate = sample_rate
# ---> 52     freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
#      53     delta = 2 * math.pi * freq / sample_rate
#      54     cummulative = torch.cumsum(delta, dim=0)
#
# Cell In[5], line 24, in _get_log_freq(sample_rate, max_sweep_rate, offset)
#      18 """Get freqs evenly spaced out in log-scale, between [0, max_sweep_rate // 2]
#      19
#      20 offset is used to avoid negative infinity `log(offset + x)`.
#      21
#      22 """
#      23 start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
# ---> 24 return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset
#
# NameError: name 'torch' is not defined

# %%
# 1. 필요한 라이브러리들을 모두 import 합니다.
import torch
import torchaudio
import math
import matplotlib.pyplot as plt
from IPython.display import Audio

# 2. 튜토리얼에서 사용하는 헬퍼(보조) 함수들을 정의합니다.
# 이 함수들 내부에서 torch, math 라이브러리를 사용하므로, import가 먼저 실행되어야 합니다.
DEFAULT_OFFSET = 201

def _get_log_freq(sample_rate, max_sweep_rate, offset):
    """주파수를 로그 스케일로 생성합니다."""
    start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
    return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset

def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
    """사인파(sine wave)를 생성합니다."""
    max_sweep_rate = sample_rate
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    delta = 2 * math.pi * freq / sample_rate
    cummulative = torch.cumsum(delta, dim=0)
    waveform = torch.sin(cummulative).unsqueeze(dim=0)
    return waveform

def plot_sweep(waveform, sample_rate, title, max_sweep_rate=None, offset=DEFAULT_OFFSET):
    """파형과 스펙트로그램을 함께 그립니다."""
    if max_sweep_rate is None:
        max_sweep_rate = sample_rate
    
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    
    plt.figure(figsize=(10, 4))
    
    # Waveform 그리기
    plt.subplot(1, 2, 1)
    plt.plot(waveform.t().numpy())
    plt.title(f"{title} - Waveform")
    
    # Spectrogram 그리기
    plt.subplot(1, 2, 2)
    plt.specgram(waveform.squeeze().numpy(), Fs=sample_rate)
    plt.plot(freq.numpy(), color="r") # 스펙트로그램 위에 주파수 변화를 빨간 선으로 표시
    plt.title(f"{title} - Spectrogram")
    
    plt.tight_layout()
    plt.show()


# 3. 이제 원래 실행하려던 코드를 실행합니다.
sample_rate = 48000
waveform = get_sine_sweep(sample_rate)

plot_sweep(waveform, sample_rate, title="Original Waveform")
Audio(waveform.numpy()[0], rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate = 48000
waveform = get_sine_sweep(sample_rate)

plot_sweep(waveform, sample_rate, title="Original Waveform")
Audio(waveform.numpy()[0], rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
resample_rate = 32000
resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
resampled_waveform = resampler(waveform)

plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
Audio(resampled_waveform.numpy()[0], rate=resample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 resample_rate = 32000
# ----> 2 resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
#       3 resampled_waveform = resampler(waveform)
#       5 plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
#
# NameError: name 'T' is not defined

# %%
resample_rate = 32000
# 리샘플링을 수행할 '도구'를 만듭니다. (48000Hz -> 32000Hz)
resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
# 실제 변환을 실행합니다.
resampled_waveform = resampler(waveform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 resample_rate = 32000
#       2 # 리샘플링을 수행할 '도구'를 만듭니다. (48000Hz -> 32000Hz)
# ----> 3 resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
#       4 # 실제 변환을 실행합니다.
#       5 resampled_waveform = resampler(waveform)
#
# NameError: name 'T' is not defined

# %%
resample_rate = 32000
resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
resampled_waveform = resampler(waveform)

plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
Audio(resampled_waveform.numpy()[0], rate=resample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 resample_rate = 32000
# ----> 2 resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
#       3 resampled_waveform = resampler(waveform)
#       5 plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
#
# NameError: name 'T' is not defined

# %%
# 1. 필요한 라이브러리들을 다시 import 합니다.
import torch
import torchaudio.transforms as T # <-- 'T'라는 별명을 여기서 정의합니다!
import math
import matplotlib.pyplot as plt
from IPython.display import Audio

# 2. 이전에 정의했던 헬퍼 함수들이 필요합니다.
# (만약 이 함수들이 정의된 셀이 초기화되었다면 NameError가 또 발생할 수 있습니다.)
DEFAULT_OFFSET = 201

def _get_log_freq(sample_rate, max_sweep_rate, offset):
    start, stop = math.log(offset), math.log(offset + max_sweep_rate // 2)
    return torch.exp(torch.linspace(start, stop, sample_rate, dtype=torch.double)) - offset

def get_sine_sweep(sample_rate, offset=DEFAULT_OFFSET):
    max_sweep_rate = sample_rate
    freq = _get_log_freq(sample_rate, max_sweep_rate, offset)
    delta = 2 * math.pi * freq / sample_rate
    cummulative = torch.cumsum(delta, dim=0)
    signal = torch.sin(cummulative).unsqueeze(dim=0)
    return signal

def plot_sweep(waveform, sample_rate, title, max_sweep_rate=48000, offset=DEFAULT_OFFSET):
    # (튜토리얼의 plot_sweep 함수를 그대로 가져왔습니다)
    x_ticks = [100, 500, 1000, 5000, 10000, 20000, max_sweep_rate // 2]
    y_ticks = [1000, 5000, 10000, 20000, sample_rate // 2]
    # ... (함수 정의의 나머지 부분)
    figure, axis = plt.subplots(1, 1)
    _, _, _, cax = axis.specgram(waveform[0].numpy(), Fs=sample_rate)
    axis.set_xlabel("Original Signal Frequency (Hz, log scale)")
    axis.set_ylabel("Waveform Frequency (Hz)")
    figure.suptitle(f"{title} (sample rate: {sample_rate} Hz)")
    plt.colorbar(cax)
    plt.show()

# 3. 리샘플링할 원본 파형을 먼저 정의해야 합니다.
sample_rate = 48000
waveform = get_sine_sweep(sample_rate)

# 4. 이제 원래 실행하려던 리샘플링 코드를 실행합니다.
resample_rate = 32000
resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
resampled_waveform = resampler(waveform)

plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
Audio(resampled_waveform.numpy()[0], rate=resample_rate)
resampled_waveform = F.resample(
    waveform,
    sample_rate,
    resample_rate,
    lowpass_filter_width=64,
    rolloff=0.9475937167399596,
    resampling_method="sinc_interp_kaiser",
    beta=14.769656459379492,
)
plot_sweep(resampled_waveform, resample_rate, title="Kaiser Window Best (torchaudio)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 48
#      46 plot_sweep(resampled_waveform, resample_rate, title="Resampled Waveform")
#      47 Audio(resampled_waveform.numpy()[0], rate=resample_rate)
# ---> 48 resampled_waveform = F.resample(
#      49     waveform,
#      50     sample_rate,
#      51     resample_rate,
#      52     lowpass_filter_width=64,
#      53     rolloff=0.9475937167399596,
#      54     resampling_method="sinc_interp_kaiser",
#      55     beta=14.769656459379492,
#      56 )
#      57 plot_sweep(resampled_waveform, resample_rate, title="Kaiser Window Best (torchaudio)")
#
# NameError: name 'F' is not defined
