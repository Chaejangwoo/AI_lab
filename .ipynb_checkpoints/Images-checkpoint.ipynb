# %%
# 1. 테스트할 이미지 파일의 '상대' 경로를 지정합니다.
#    'data_dir' 변수를 기준으로 한 상대적인 경로입니다.
#    예를 들어, 'val' 폴더 안의 'cats' 폴더 안의 'cat.4095.jpg' 파일을 사용합니다.
relative_image_path = 'val/cats/cat.4095.jpg'

# 2. 이전에 데이터 로딩 시 만들었던 절대 경로 변수 'data_dir'와 합쳐서
#    이미지 파일의 완전한 절대 경로를 만듭니다.
#    (data_dir 변수가 정의된 셀을 먼저 실행해야 합니다)
absolute_image_path = os.path.join(data_dir, relative_image_path)

print(f"테스트할 이미지의 전체 경로: {absolute_image_path}")


# 3. 이제 이 절대 경로를 사용하여 예측 함수를 호출합니다.
#    이전에 학습시킨 '특징 추출' 방식의 모델(model_conv)로 예측을 수행합니다.
visualize_model_predictions(
    model_conv,
    img_path=absolute_image_path
)

# 4. Matplotlib의 대화형 모드를 끄고, 최종 plot을 화면에 고정하여 보여줍니다.
plt.ioff()
plt.show()
# Out:
# 테스트할 이미지의 전체 경로: /Users/chaejang-u/Desktop/인공지능/data/sample_computer_vision/val/cats/cat.4095.jpg
