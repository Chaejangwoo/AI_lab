# %%
import torch
import torchaudio

torch.random.manual_seed(0)
device = "cuda" if torch.cuda.is_available() else "cpu"

print(torch.__version__)
print(torchaudio.__version__)
print(device)
# Out:
# 2.8.0
# 2.8.0
# cpu

# %%
import IPython
import matplotlib.pyplot as plt

# %%
symbols = "_-!'(),.:;? abcdefghijklmnopqrstuvwxyz"
look_up = {s: i for i, s in enumerate(symbols)}
symbols = set(symbols)


def text_to_sequence(text):
    text = text.lower()
    return [look_up[s] for s in text if s in symbols]


text = "Hello world! Text to speech!"
print(text_to_sequence(text))
# Out:
# [19, 16, 23, 23, 26, 11, 34, 26, 29, 23, 15, 2, 11, 31, 16, 35, 31, 11, 31, 26, 11, 30, 27, 16, 16, 14, 19, 2]

# %%
processor = torchaudio.pipelines.TACOTRON2_WAVERNN_CHAR_LJSPEECH.get_text_processor()

text = "Hello world! Text to speech!"
processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# tensor([[19, 16, 23, 23, 26, 11, 34, 26, 29, 23, 15,  2, 11, 31, 16, 35, 31, 11,
#          31, 26, 11, 30, 27, 16, 16, 14, 19,  2]])
# tensor([28], dtype=torch.int32)

# %%
print([processor.tokens[i] for i in processed[0, : lengths[0]]])
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', ' ', 't', 'e', 'x', 't', ' ', 't', 'o', ' ', 's', 'p', 'e', 'e', 'c', 'h', '!']

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()

text = "Hello world! Text to speech!"
with torch.inference_mode():
    processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH
# ----> 3 processor = bundle.get_text_processor()
#       5 text = "Hello world! Text to speech!"
#       6 with torch.inference_mode():
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/pipelines/_tts/impl.py:140, in _PhoneMixin.get_text_processor(self, dl_kwargs)
#     139 def get_text_processor(self, *, dl_kwargs=None) -> Tacotron2TTSBundle.TextProcessor:
# --> 140     return _EnglishPhoneProcessor(dl_kwargs=dl_kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/pipelines/_tts/impl.py:47, in _EnglishPhoneProcessor.__init__(self, dl_kwargs)
#      45 self._tokens = utils._get_phones()
#      46 self._mapping = {p: i for i, p in enumerate(self._tokens)}
# ---> 47 self._phonemizer = utils._load_phonemizer("en_us_cmudict_forward.pt", dl_kwargs=dl_kwargs)
#      48 self._pattern = r"(\[[A-Z]+?\]|[_!'(),.:;? -])"
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torchaudio/pipelines/_tts/utils.py:161, in _load_phonemizer(file, dl_kwargs)
#     159 def _load_phonemizer(file, dl_kwargs):
#     160     if not _mod_utils.is_module_available("dp"):
# --> 161         raise RuntimeError("DeepPhonemizer is not installed. Please install it.")
#     163     from dp.phonemizer import Phonemizer
#     164     from dp.preprocessing.text import Preprocessor, LanguageTokenizer, SequenceTokenizer
#
# RuntimeError: DeepPhonemizer is not installed. Please install it.

# %%
pip install deep_phonemizer
# Out:
# Collecting deep_phonemizer
#   Using cached deep-phonemizer-0.0.19.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (2.8.0)
# Collecting tqdm>=4.38.0 (from deep_phonemizer)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (6.0.2)
# Collecting tensorboard (from deep_phonemizer)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: certifi>=2022.12.7 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (2025.8.3)
# Requirement already satisfied: wheel>=0.38.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (0.45.1)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from deep_phonemizer) (78.1.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (1.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from torch>=1.2.0->deep_phonemizer) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.2.0->deep_phonemizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from jinja2->torch>=1.2.0->deep_phonemizer) (3.0.2)
# Collecting absl-py>=0.4 (from tensorboard->deep_phonemizer)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->deep_phonemizer)
#   Downloading grpcio-1.75.1-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard->deep_phonemizer)
#   Using cached markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (2.2.6)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (25.0)
# Requirement already satisfied: pillow in /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages (from tensorboard->deep_phonemizer) (11.3.0)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard->deep_phonemizer)
#   Using cached protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->deep_phonemizer)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->deep_phonemizer)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading grpcio-1.75.1-cp310-cp310-macosx_11_0_universal2.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 39.1 MB/s  0:00:0042.8 MB/s eta 0:00:01
# Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Using cached protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Building wheels for collected packages: deep_phonemizer
#   DEPRECATION: Building 'deep_phonemizer' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'deep_phonemizer'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for deep_phonemizer (setup.py) ... done
#   Created wheel for deep_phonemizer: filename=deep_phonemizer-0.0.19-py3-none-any.whl size=33357 sha256=4438a60b4c13dfddac2b372bcd03b6bf62bf61287882974c3633528315d7d4d0
#   Stored in directory: /Users/chaejang-u/Library/Caches/pip/wheels/c7/61/da/39b050eea5710fe32b1521b79de4a74d95896581230d30a37b
# Successfully built deep_phonemizer
# Installing collected packages: werkzeug, tqdm, tensorboard-data-server, protobuf, markdown, grpcio, absl-py, tensorboard, deep_phonemizer
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [deep_phonemizer]7/9 [tensorboard]py]
# Successfully installed absl-py-2.3.1 deep_phonemizer-0.0.19 grpcio-1.75.1 markdown-3.9 protobuf-6.32.1 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tqdm-4.67.1 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()

text = "Hello world! Text to speech!"
with torch.inference_mode():
    processed, lengths = processor(text)

print(processed)
print(lengths)
# Out:
# 100.0%
# tensor([[54, 20, 65, 69, 11, 92, 44, 65, 38,  2, 11, 81, 40, 64, 79, 81, 11, 81,
#          20, 11, 79, 77, 59, 37,  2]])
# tensor([25], dtype=torch.int32)
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
print([processor.tokens[i] for i in processed[0, : lengths[0]]])
# Out:
# ['HH', 'AH', 'L', 'OW', ' ', 'W', 'ER', 'L', 'D', '!', ' ', 'T', 'EH', 'K', 'S', 'T', ' ', 'T', 'AH', ' ', 'S', 'P', 'IY', 'CH', '!']

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH
processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)

text = "Hello world! Text to speech!"

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, _, _ = tacotron2.infer(processed, lengths)


_ = plt.imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")
# Out:
# 2.7%
# Downloading: "https://download.pytorch.org/torchaudio/models/tacotron2_english_phonemes_1500_epochs_wavernn_ljspeech.pth" to /Users/chaejang-u/.cache/torch/hub/checkpoints/tacotron2_english_phonemes_1500_epochs_wavernn_ljspeech.pth
# 100.0%

# %%
def plot():
    fig, ax = plt.subplots(3, 1)
    for i in range(3):
        with torch.inference_mode():
            spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
        print(spec[0].shape)
        ax[i].imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")


plot()
# Out:
# torch.Size([80, 179])
# torch.Size([80, 177])
# torch.Size([80, 214])

# %%
bundle = torchaudio.pipelines.TACOTRON2_WAVERNN_PHONE_LJSPEECH

processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)
vocoder = bundle.get_vocoder().to(device)

text = "Hello world! Text to speech!"

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
    waveforms, lengths = vocoder(spec, spec_lengths)
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wavernn_10k_epochs_8bits_ljspeech.pth" to /Users/chaejang-u/.cache/torch/hub/checkpoints/wavernn_10k_epochs_8bits_ljspeech.pth
# 100.0%

# %%
def plot(waveforms, spec, sample_rate):
    waveforms = waveforms.cpu().detach()

    fig, [ax1, ax2] = plt.subplots(2, 1)
    ax1.plot(waveforms[0])
    ax1.set_xlim(0, waveforms.size(-1))
    ax1.grid(True)
    ax2.imshow(spec[0].cpu().detach(), origin="lower", aspect="auto")
    return IPython.display.Audio(waveforms[0:1], rate=sample_rate)


plot(waveforms, spec, vocoder.sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
bundle = torchaudio.pipelines.TACOTRON2_GRIFFINLIM_PHONE_LJSPEECH

processor = bundle.get_text_processor()
tacotron2 = bundle.get_tacotron2().to(device)
vocoder = bundle.get_vocoder().to(device)

with torch.inference_mode():
    processed, lengths = processor(text)
    processed = processed.to(device)
    lengths = lengths.to(device)
    spec, spec_lengths, _ = tacotron2.infer(processed, lengths)
waveforms, lengths = vocoder(spec, spec_lengths)
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/tacotron2_english_phonemes_1500_epochs_ljspeech.pth" to /Users/chaejang-u/.cache/torch/hub/checkpoints/tacotron2_english_phonemes_1500_epochs_ljspeech.pth
# 100.0%

# %%
plot(waveforms, spec, vocoder.sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Workaround to load model mapped on GPU
# https://stackoverflow.com/a/61840832
waveglow = torch.hub.load(
    "NVIDIA/DeepLearningExamples:torchhub",
    "nvidia_waveglow",
    model_math="fp32",
    pretrained=False,
)
checkpoint = torch.hub.load_state_dict_from_url(
    "https://api.ngc.nvidia.com/v2/models/nvidia/waveglowpyt_fp32/versions/1/files/nvidia_waveglowpyt_fp32_20190306.pth",  # noqa: E501
    progress=False,
    map_location=device,
)
state_dict = {key.replace("module.", ""): value for key, value in checkpoint["state_dict"].items()}

waveglow.load_state_dict(state_dict)
waveglow = waveglow.remove_weightnorm(waveglow)
waveglow = waveglow.to(device)
waveglow.eval()

with torch.no_grad():
    waveforms = waveglow.infer(spec)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/NVIDIA/DeepLearningExamples/zipball/torchhub" to /Users/chaejang-u/.cache/torch/hub/torchhub.zip
# /Users/chaejang-u/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /Users/chaejang-u/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_lab/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Downloading: "https://api.ngc.nvidia.com/v2/models/nvidia/waveglowpyt_fp32/versions/1/files/nvidia_waveglowpyt_fp32_20190306.pth" to /Users/chaejang-u/.cache/torch/hub/checkpoints/nvidia_waveglowpyt_fp32_20190306.pth
